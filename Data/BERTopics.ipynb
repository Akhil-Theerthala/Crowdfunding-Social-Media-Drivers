# %%
# !pip install bertopic

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired
from sklearn.model_selection import train_test_split


def set_seed(seed_value):
    random.seed(seed_value)
    np.random.seed(seed_value)
    pd.set_option('mode.chained_assignment', None)
    torch.manual_seed(seed_value)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

set_seed(42)


representation_model = KeyBERTInspired()
df = pd.read_csv('cleaned_data.csv')
text_docs = df.post_text.str.strip("'[]")
text_docs =text_docs.str.replace("'","").str.replace(",","").str.lstrip()
# Out:
# 0                                                     NaN
# 1       Artist and designer Janos Stone is creating a ...
# 2       The inaugural meeting of Kickstarter’s Communi...
# 3       This 25-year-old man rushed into a burning hou...
# 4       An occult-themed JRPG with a fully integrated ...
#                               ...
# 9522    This curated collection of Taiwanese teas come...
# 9523    A luxurious shower head that cleans better and...
# 9524                                                  NaN
# 9525                                                  NaN
# 9526    "If it’s not fun, it’s not worth doing."On mak...
# Length: 9527, dtype: object

# %%
text_docs
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 9522    NaN
# 9523    NaN
# 9524    NaN
# 9525    NaN
# 9526    NaN
# Length: 9527, dtype: object

# %%
text_docs = text_docs[text_docs != ''].reset_index(drop=True)

# %%
text_docs
# Out:
# 0       preserve portrait possible service veteran sac...
# 1       stone unique mini recyclable truly age playhou...
# 2       feedback discussion frank inaugural meeting co...
# 3       25yearold aid recovery rush five verify burn p...
# 4       jrpg count fully deck integrate tarot occult e...
#                               ...
# 8770    curate magazine print collection tea authentic...
# 8771    less 75 clean luxurious shower percent less 75...
# 8772    construct spare marble mason gold kit diy marb...
# 8773                  link 15 48 additional plus ultimate
# 8774    worth fun harness kevin magic microbe educatio...
# Name: post_text, Length: 8775, dtype: object

# %%
topic_model = BERTopic(embedding_model="all-MiniLM-L12-v2", verbose=True,
                       min_topic_size = 75)
topics, probs = topic_model.fit_transform(text_docs)
# Out:
# 2023-12-24 10:47:17,982 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/275 [00:00<?, ?it/s]
# 2023-12-24 10:47:25,691 - BERTopic - Embedding - Completed ✓
# 2023-12-24 10:47:25,697 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2023-12-24 10:47:41,152 - BERTopic - Dimensionality - Completed ✓
# 2023-12-24 10:47:41,154 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2023-12-24 10:47:41,709 - BERTopic - Cluster - Completed ✓
# 2023-12-24 10:47:41,717 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2023-12-24 10:47:41,935 - BERTopic - Representation - Completed ✓

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b579ad7f-7503-46e4-90a2-93af37f4d551" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b579ad7f-7503-46e4-90a2-93af37f4d551")) {                    Plotly.newPlot(                        "b579ad7f-7503-46e4-90a2-93af37f4d551",                        [{"customdata":[[0,"musician | comic_strip | magazine | director | process",1196],[1,"shooting | kill | rare | baby | hurricane",733],[2,"phone | smartphone | charger | solar | station",449],[3,"backpack | electric | ride | scooter | luggage",257],[4,"coffee | bottle | brew | drink | craft",199],[5,"christmas | santa | holiday | toy | steal",157],[6,"earbud | speaker | headphone | bluetooth | audio",146],[7,"political | organization | equality | justice | social",140],[8,"chef | kitchen | cook | cooking | recipe",123],[9,"feed | meal | lunch | hungry | restaurant",120],[10,"veteran | vet | wwii | war | flag",111],[11,"robot | robotic | code | ai | teach",110],[12,"sleep | pillow | wake | smartwatch | wearable",109],[13,"giving | givingtuesday | tuesday | donation | gofundmes",99],[14,"sign | virtual | hangout | ntentsignuprfbksocvirtualh | iggvirtualhangouts",98],[15,"gym | workout | fitness | body | exercise",97],[16,"pup | pet | shelter | rescue | puppy",85]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[1196,733,449,257,199,157,146,140,123,120,111,110,109,99,98,97,85],"sizemode":"area","sizeref":0.7475,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[30.53534507751465,8.621072769165039,3.7529678344726562,2.712675094604492,30.24399757385254,9.077220916748047,4.284588813781738,30.338815689086914,30.046781539916992,29.838069915771484,8.331474304199219,3.020411491394043,4.430774688720703,8.878942489624023,30.73727035522461,2.345677614212036,8.9033203125],"xaxis":"x","y":[12.58800220489502,-3.0852670669555664,-6.080349445343018,-5.988595962524414,-12.61681842803955,-2.5080718994140625,-6.093474864959717,12.7844820022583,-12.419540405273438,-12.210806846618652,-3.3107643127441406,-6.282894611358643,-6.300655841827393,-2.2338082790374756,12.386077880859375,-6.387449741363525,-3.2768049240112305],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"o ...

# %%
topic_distr, _ = topic_model.approximate_distribution(text_docs)
# Out:
# 100%|██████████| 9/9 [00:01<00:00,  7.26it/s]

# %%
topic_model.get_document_info(text_docs)
# Out:
#                                                Document  Topic  \
# 0     preserve portrait possible service veteran sac...     10
# 1     stone unique mini recyclable truly age playhou...      0
# 2     feedback discussion frank inaugural meeting co...      0
# 3     25yearold aid recovery rush five verify burn p...      1
# 4     jrpg count fully deck integrate tarot occult e...     -1
# ...                                                 ...    ...
# 8770  curate magazine print collection tea authentic...      0
# 8771  less 75 clean luxurious shower percent less 75...     -1
# 8772  construct spare marble mason gold kit diy marb...     -1
# 8773                link 15 48 additional plus ultimate      6
# 8774  worth fun harness kevin magic microbe educatio...     -1
#
#                                           Name  \
# 0                      10_veteran_vet_wwii_war
# 1     0_musician_comic_strip_magazine_director
# 2     0_musician_comic_strip_magazine_director
# 3                    1_shooting_kill_rare_baby
# 4              -1_gaming_podcast_cat_instagram
# ...                                        ...
# 8770  0_musician_comic_strip_magazine_director
# 8771           -1_gaming_podcast_cat_instagram
# 8772           -1_gaming_podcast_cat_instagram
# 8773      6_earbud_speaker_headphone_bluetooth
# 8774           -1_gaming_podcast_cat_instagram
#
#                                          Representation  \
# 0     [veteran, vet, wwii, war, flag, pilot, militar...
# 1     [musician, comic_strip, magazine, director, pr...
# 2     [musician, comic_strip, magazine, director, pr...
# 3     [shooting, kill, rare, baby, hurricane, diseas...
# 4     [gaming, podcast, cat, instagram, ig, differen...
# ...                                                 ...
# 8770  [musician, comic_strip, magazine, director, pr...
# 8771  [gaming, podcast, cat, instagram, ig, differen...
# 8772  [gaming, podcast, cat, instagram, ig, differen...
# 8773  [earbud, speaker, headphone, bluetooth, audio,...
# 8774  [gaming, podcast, cat, instagram, ig, differen...
#
#                                     Representative_Docs  \
# 0     [veteran tyler veteran 3000 8yearold nearly ve...
# 1     [sign draft page cornerstone worth chance link...
# 2     [sign draft page cornerstone worth chance link...
# 3     [diagnosis 2yearold rare 12 rare disease affec...
# 4     [brand podcast listen season subscribe link tr...
# ...                                                 ...
# 8770  [sign draft page cornerstone worth chance link...
# 8771  [brand podcast listen season subscribe link tr...
# 8772  [brand podcast listen season subscribe link tr...
# 8773  [earbud language translate shipping earbud tra...
# 8774  [brand podcast listen season subscribe link tr...
#
#                                             Top_n_words  Probability  \
# 0     veteran - vet - wwii - war - flag - pilot - mi...     1.000000
# 1     musician - comic_strip - magazine - director -...     0.978060
# 2     musician - comic_strip - magazine - director -...     1.000000
# 3     shooting - kill - rare - baby - hurricane - di...     0.995632
# 4     gaming - podcast - cat - instagram - ig - diff...     0.000000
# ...                                                 ...          ...
# 8770  musician - comic_strip - magazine - director -...     0.989557
# 8771  gaming - podcast - cat - instagram - ig - diff...     0.000000
# 8772  gaming - podcast - cat - instagram - ig - diff...     0.000000
# 8773  earbud - speaker - headphone - bluetooth - aud...     0.305663
# 8774  gaming - podcast - cat - instagram - ig - diff...     0.000000
#
#       Representative_document
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 8770                    False
# 8771                    False
# 8772                    False
# 8773                    False
# 8774                    False
#
# [8775 rows x 8 columns]

# %%
topic_model.probabilities_
# Out:
# array([1., 1., 1., ..., 0., 0., 0.])

# %%
topic_labels = topic_model.generate_topic_labels(nr_words=30,
                                            topic_prefix=True,
                                            word_length=30,
                                            separator=", ")

topic_idx = [x.split(',')[0] for x in topic_labels]
topic_words = [','.join(x.split(',')[1:]) for x in topic_labels]
topic_label_df= pd.DataFrame(columns=['topic_idx', 'topic_words'])
topic_label_df['topic_idx'] = topic_idx
topic_label_df['topic_words'] = topic_words
topic_label_df
# Out:
#   topic_idx                                        topic_words
# 0        -1   robot, podcast, episode, ig, gaming, 3d, inst...
# 1         0   sign, stranger, christmas, walk, veteran, bab...
# 2         1   charger, smartphone, phone, solar, laptop, ba...
# 3         2   electric, ride, backpack, scooter, luggage, f...
# 4         3   earbud, speaker, headphone, bluetooth, audio,...
# 5         4   gym, workout, body, fitness, exercise, fat, t...
# 6         5   sleep, pillow, smartwatch, wake, wearable, im...

# %%
topic_labels = topic_model_2.generate_topic_labels(nr_words=30,
                                            topic_prefix=True,
                                            word_length=30,
                                            separator=", ")

topic_idx = [x.split(',')[0] for x in topic_labels]
topic_words = [','.join(x.split(',')[1:]) for x in topic_labels]
topic_label_df= pd.DataFrame(columns=['topic_idx', 'topic_words'])
topic_label_df['topic_idx'] = topic_idx
topic_label_df['topic_words'] = topic_words
topic_label_df
# Out:
#    topic_idx                                        topic_words
# 0         -1   print, toy, social, news, nonprofit, special,...
# 1          0   bootcamp, startup, ces2018, prelaunch, hardwa...
# 2          1   ride, segway, segwayninebot, segways, scooter...
# 3          2   tarot, cards, deck, card, divination, diverse...
# 4          3   earbud, bluetooth, wearbud, earphone, airpod,...
# 5          4   charger, charging, powerbank, batterys, recha...
# 6          5   comic_strip, comics, comic, manga, graphic, c...
# 7          6   lunch, debt, meal, lunchbox, hungry, hunger, ...
# 8          7   hurricane, harvey, irma, storm, houston, texa...
# 9          8   workout, fitness, exercise, trainer, gym, fit...
# 10         9   cure, genetic, rare, disease, treatment, diag...
# 11        10   hammock, camping, tent, camp, backpack, outdo...
# 12        11   advice, procrastination, tci, failure, fail, ...
# 13        12   cook, chef, cooking, cookware, sear, sauté, c...
# 14        13   kickstarterfunde, kickstarterfunded, sxsw, fe...
# 15        14   givingtuesday, giving, nonprofit, generosity,...
# 16        15   shooting, shooter, gunman, shoot, firearm, te...
# 17        16   barista, coffee, brew, brewing, baristaqualit...
# 18        17   musician, songwriter, songwriting, collaborat...
# 19        18   pandemic, coronavirus, covid, outbreak, crisi...
# 20        19   robot, robotics, robotic, robotical, ai, mach...
# 21        20   vpn, firewall, security, firewalla, router, s...
# 22        21   sleep, sleepsmart, sleeping, bedtime, slumber...
# 23        22   veteran, veterans, tyler, vet, veteransday, b...
# 24        23   pet, vet, pup, veterinary, doggo, dogs, adopt...
# 25        24   museum, curator, exhibition, collection, smit...
# 26        25   footwear, shoe, sneaker, wear, breathable, fo...
# 27        26   ntentsignuprfbksocvirtualh, hangouts, hangout...
# 28        27   bottle, plastic, recyclable, recycled, recycl...
# 29        28   anamorphic, lens, photography, photographie, ...
# 30        29   activist, antiracism, initiative, solidarity,...
# 31        30   elderly, repair, fix, senior, disabled, potho...
# 32        31   lgbtq, lgbt, lgbtqia, queer, pride, gay, tran...
# 33        32   voyager, nasa, spacecraft, earth, astronaut, ...
# 34        33   podcasts, podcast, podcaster, podcatcher, epi...
# 35        34   santas, santa, christmas, december, claus, ho...
# 36        35   midi, instrument, musicandtech, synth, synthe...
# 37        36   instagram, instagramcomindiegogo, ig, inspo, ...
# 38        37   purifier, purify, humidifier, air, purificati...
# 39        38   earthday, howitworkstalkgreenproductsign, app...
# 40        39   accident, fatal, crash, tragedy, tragic, trag...
# 41        40   softlight, selfie, night, photography, gimbal...
# 42        41   haircut, barber, barbershop, hair, salon, hai...
# 43        42   officer, police, cop, deputy, duty, enforceme...

# %%
topic_model.get_topic(16)

# %%
topic_model.visualize_hierarchy(top_n_topics=10)

# %%
topic_model.visualize_barchart(top_n_topics=10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5e0a682f-3796-4f3c-a952-12f6f4628cb8" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e0a682f-3796-4f3c-a952-12f6f4628cb8")) {                    Plotly.newPlot(                        "5e0a682f-3796-4f3c-a952-12f6f4628cb8",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.7323098182678223,0.772930383682251,0.7815636396408081,0.7819700837135315,0.7951292991638184],"y":["literary  ","comic  ","comics  ","magazine  ","comic_strip  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.7139250040054321,0.718104362487793,0.718724250793457,0.7246462106704712,0.7308915853500366],"y":["genetic  ","miracle  ","rare  ","disease  ","cure  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.7352787256240845,0.7363812923431396,0.7431550025939941,0.7558794021606445,0.7623815536499023],"y":["environment  ","reusable  ","sustainability  ","sustainable  ","ecofriendly  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.7289438247680664,0.7371839284896851,0.7665509581565857,0.7676546573638916,0.781988263130188],"y":["usbc  ","solar  ","charging  ","powerbank  ","charger  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0